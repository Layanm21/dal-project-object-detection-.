# %% [markdown]
# # DAL Shemagh Detection - Colab Notebook
#
# Use this notebook after uploading the lightweight project files to Colab.

# %% [markdown]
# ## 1) Upload Required Files
#
# Upload these files to `/content/dal`:
# - `run_all.py`
# - `02_train_yolo.py`
# - `03_inference_and_classification_v2.py`
# - `data.yaml`
# - `requirements.txt`
# - `train_labels.csv`
# - `kaggle.json`

# %%
# %cd /content
# !mkdir -p /content/dal
# %cd /content/dal
# !ls -lh

# %% [markdown]
# ## 2) Install Requirements

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 3) Setup Kaggle API

# %%
# !mkdir -p ~/.kaggle
# !cp /content/dal/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions list | head -5

# %% [markdown]
# ## 4) Environment Check

# %%
import os
from pathlib import Path
import torch

print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

print("\nFiles:")
for f in ["run_all.py", "data.yaml", "requirements.txt", "kaggle.json"]:
    print(f"- {f}: {os.path.exists(f)}")

if Path("images/train").exists():
    print(f"\nTrain images: {len(list(Path('images/train').glob('*.jpg')))}")
if Path("images/test").exists():
    print(f"Test images: {len(list(Path('images/test').glob('*.jpg')))}")

# %% [markdown]
# ## 5) Run Pipeline
#
# Quick mode (recommended first run):

# %%
# !python run_all.py --download --quick

# %% [markdown]
# Optional commands:

# %%
# Full mode:
# !python run_all.py --download

# Train only:
# !python run_all.py --download --train-only --quick

# Inference only (after training):
# !python run_all.py --inference-only

# %% [markdown]
# ## 6) Download Results

# %%
from google.colab import files

files.download('submission.csv')
# files.download('runs/detect/weights/best.pt')
